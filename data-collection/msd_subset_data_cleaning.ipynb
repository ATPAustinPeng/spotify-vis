# %%
import pandas

# %%
df = pandas.read_csv('../data/msd_subset_data_songs_unclean.csv')

# %%
df.head()
# Out:
#    analysis_sample_rate                         audio_md5  danceability  \
# 0                 22050  d8bafd4a65d1855aec08991c8b013dc1           0.0
# 1                 22050  55f60c97280172e9276723c06e531996           0.0
# 2                 22050  053fb50807248bef996e6c7a5fe93533           0.0
# 3                 22050  1637df8efe4d89507b6f4ef89a82cacf           0.0
# 4                 22050  ad4e2031b81e71567fcb7ee46708d255           0.0
#
#     duration  end_of_fade_in  energy  idx_bars_confidence  idx_bars_start  \
# 0  148.74077           0.192     0.0                    0               0
# 1  252.99546           0.514     0.0                    0               0
# 2   78.02730           0.974     0.0                    0               0
# 3  163.63057           0.000     0.0                    0               0
# 4  199.99302           0.000     0.0                    0               0
#
#    idx_beats_confidence  idx_beats_start  ...  idx_artist_terms  \
# ...

# %% [markdown]
# # Data Cleaning
# - drop zeros, drop none/nan, drop duplicates (same song name and artist name, but might want to avg ratings, etc.)

# %%
for col in df.columns:
    if (df[col] == 0).all(): # drop the column if all values are zero (Note: why are danceability and energy columns of 0?)
        print(col)
        df.drop(col, axis=1, inplace=True)
# Out:
# danceability
# energy
# idx_bars_confidence
# idx_bars_start
# idx_beats_confidence
# idx_beats_start
# idx_sections_confidence
# idx_sections_start
# idx_segments_confidence
# idx_segments_loudness_max
# idx_segments_loudness_max_time
# idx_segments_loudness_start
# idx_segments_pitches
# idx_segments_start
# idx_segments_timbre
# idx_tatums_confidence
# idx_tatums_start
# idx_artist_terms
# idx_similar_artists
# idx_artist_mbtags

# %%
df.head()
# Out:
#    analysis_sample_rate                         audio_md5   duration  \
# 0                 22050  d8bafd4a65d1855aec08991c8b013dc1  148.74077
# 1                 22050  55f60c97280172e9276723c06e531996  252.99546
# 2                 22050  053fb50807248bef996e6c7a5fe93533   78.02730
# 3                 22050  1637df8efe4d89507b6f4ef89a82cacf  163.63057
# 4                 22050  ad4e2031b81e71567fcb7ee46708d255  199.99302
#
#    end_of_fade_in  key  key_confidence  loudness  mode  mode_confidence  \
# 0           0.192    0           0.591    -9.636     1            0.556
# 1           0.514    1           0.429   -11.061     0            0.670
# 2           0.974    3           0.000   -24.140     1            0.000
# 3           0.000    7           0.380    -5.795     1            0.385
# 4           0.000   10           0.551   -16.477     1            0.528
#
#    start_of_fade_out  ...             artist_name  artist_playmeid  genre  \
# ...

# %%
df.isna().sum()
# Out:
# analysis_sample_rate             0
# audio_md5                        0
# duration                         0
# end_of_fade_in                   0
# key                              0
# key_confidence                   0
# loudness                         0
# mode                             0
# mode_confidence                  0
# start_of_fade_out                0
# tempo                            0
# time_signature                   0
# time_signature_confidence        0
# track_id                         0
# analyzer_version             10000
# artist_7digitalid                0
# artist_familiarity               4
# artist_hotttnesss                0
# artist_id                        0
# artist_latitude               6258
# artist_location               4292
# artist_longitude              6258
# artist_mbid                    719
# artist_name                      0
# artist_playmeid                  0
# genre                        10000
# release                          0
# ...

# %% [markdown]
# # Altering Data
# - use `end_of_fade_in` and `start_of_fade_out` to calculate `not_silent_duration`
